# %% [markdown]
# ### College of Computing and Informatics, Drexel University
# ### INFO 212: Data Science Programming I, Spring 2018
# ---
#
# ## Final Project Report
#
# ## Project Title: Cars and Cars & Cars
#
# ## Student(s): Ramir Austin
#
# #### Date: June 15th 2018
# ---

# %% [markdown]
# #### Abstract
# ---

# %% [markdown]
# This project will go over a car based dataset that unfinshed. I will cleanse the data, then show graphs of the the relations for cars through various attributes and various graphs. You will see how the make will affect the price such as Jag will cost more than Toyota but the Toyota will have better mileage.

# %% [markdown]
# ### 1. Introduction
# ---

# %% [markdown]
# For this project I wanted to look at a large database. At first I wanted to work on the titanic since it was familiar and had a ton of information then I looked towards crimes rates. The crime rates tend to be grim to look at while the Titanic seemed too familiar to work with. I decided to find a database relating to cars. I'll be showing the data in grid, graph and cluster form. Essentially it's a data analysis of this dataset for exploratory purposes that can be used a user who may be interested at a later date.

# %% [markdown]
# ### 2. Problem Definition
# ---

# %% [markdown]
# The problem is, this file has a ton of information but it's not a complete file. Even though it can be used as is, it needs to be cleansed and some columns need to be converted from a string to an integer or vice versa. Two of the columns this really needs to be done for are the horsepower and price columns. They won't be able to be graphed properly without being cleansed. People who would benefit from this being solved and shown are people who may want general data on cars in this dataset or who would want to use cleaned up and completely usable version of this dataset.

# %% [markdown]
# ### 3. Data Sources
# ---

# %% [markdown]
# The source I will be using is a .csv file. I found a couple of dataset on kaggle and decided to add some information to the dataset I found the most useful. Some of the added information is information from actual cars adn from the other datasets I viewed. You can download the files from kaggle and open them in Microsoft Excel or a Google Spreadsheet. I used this kaggle for the data and refrence for my project: https://www.kaggle.com/toramky/eda-for-automobile-dataset/data

# %% [markdown]
# ### 4. Acquiring and Loading Data
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('Automobile.csv')
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# ### 5. Exploring and Visualizing Data
# ---

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base     length       width  \
# count  203.000000         203.000000  203.000000  203.00000  203.000000
# mean     0.837438         121.871921   98.781281  174.11330   65.915271
# std      1.250021          31.784599    6.040994   12.33909    2.150274
# min     -2.000000          65.000000   86.600000  141.10000   60.300000
# 25%      0.000000         101.000000   94.500000  166.55000   64.100000
# 50%      1.000000         122.000000   97.000000  173.20000   65.500000
# 75%      2.000000         137.000000  102.400000  183.30000   66.900000
# max      3.000000         256.000000  120.900000  208.10000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  203.000000   203.000000   203.000000  199.000000  199.000000
# mean    53.731527  2557.916256   127.073892    3.330955    3.254070
# std      2.442526   522.557049    41.797123    0.274054    0.318023
# ...

# %%
sns.set_style('whitegrid')
sns.lmplot('city-mpg','engine-size',data=data,hue='make',fit_reg=False)

# %% [markdown]
# ### 6. Wrangling and Cleansing Data
# ---

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Find out number of records having '?' value for normalized losses
data['normalized-losses'].loc[data['normalized-losses'] == '?'].count()
# Out:
# 41

# %%
# Find out the number of values which are not numeric
data['price'].str.isnumeric().value_counts()
# Out:
# True     201
# False      4
# Name: price, dtype: int64

# %%
# Setting the missing value to mean of normalized losses and conver the datatype to integer
nl = data['normalized-losses'].loc[data['normalized-losses'] != '?']
nlmean = nl.astype(str).astype(int).mean()
data['normalized-losses'] = data['normalized-losses'].replace('?',nlmean).astype(int)
data['normalized-losses'].head()
# Out:
# 0    122
# 1    122
# 2    122
# 3    164
# 4    164
# Name: normalized-losses, dtype: int32

# %% [markdown]
# # Cleansing the Price

# %%
# Find out the number of values which are not numeric
data['price'].str.isnumeric().value_counts()
# Out:
# True     201
# False      4
# Name: price, dtype: int64

# %%
# List out the values which are non numeric
data['price'].loc[data['price'].str.isnumeric() == False]
# Out:
# 9      ?
# 44     ?
# 45     ?
# 129    ?
# Name: price, dtype: object

# %%
#Setting the missing value to mean of price and convert the datatype to integer
price = data['price'].loc[data['price'] != '?']
pmean = price.astype(str).astype(int).mean()
data['price'] = data['price'].replace('?',pmean).astype(int)
data['price'].head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int32

# %% [markdown]
# # Cleansing the Horsepower

# %%
# Check the numberic and replace the mean value and conver the datatype to integer
data['horsepower'].str.isnumeric().value_counts()
horsepower = data['horsepower'].loc[data['horsepower'] != '?']
hpmean = horsepower.astype(str).astype(int).mean()
data['horsepower'] = data['horsepower'].replace('?',pmean).astype(int)

# %%
#Check the outlier of horsepower
data.loc[data['horsepower'] > 10000]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 130          0                122  renault       gas        std         four
# 131          2                122  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...   engine-size  \
# 130      wagon          fwd           front        96.1  ...           132
# 131  hatchback          fwd           front        96.1  ...           132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 130         mpfi  3.46     3.9               8.7      13207         ?
# 131         mpfi  3.46     3.9               8.7      13207         ?
#
#     city-mpg highway-mpg price
# 130       23          31  9295
# 131       23          31  9895
#
# [2 rows x 26 columns]

# %%
#Excluding the outlier data for horsepower
data[np.abs(data.horsepower-data.horsepower.mean())<=(3*data.horsepower.std())]
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                122         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                122         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            0                122         audi       gas      turbo
# 10           2                192          bmw       gas        std
# 11           0                192          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %% [markdown]
# # Cleaning Boar

# %%
# Find out the number of invalid value
data['bore'].loc[data['bore'] == '?']
# Out:
# 55    ?
# 56    ?
# 57    ?
# 58    ?
# Name: bore, dtype: object

# %%
# Replace the non-numeric value to null and conver the datatype
data['bore'] = pd.to_numeric(data['bore'],errors='coerce')
data.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke                object
# compression-ratio    float64
# horsepower             int32
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int32
# dtype: object

# %% [markdown]
# # Cleansing the stroke and peak-rpm

# %%
# Replace the non-number value to null and convert the datatype
data['stroke'] = pd.to_numeric(data['stroke'],errors='coerce')
data.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int32
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int32
# dtype: object

# %%
# Convert the non-numeric data to null and convert the datatype
data['peak-rpm'] = pd.to_numeric(data['peak-rpm'],errors='coerce')
data.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int32
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int32
# dtype: object

# %% [markdown]
# # Cleansing the Number of Doors

# %%
# remove the records which are having the value '?'
data['num-of-doors'].loc[data['num-of-doors'] == '?']
data = data[data['num-of-doors'] != '?']
data['num-of-doors'].loc[data['num-of-doors'] == '?']
# Out:
# Series([], Name: num-of-doors, dtype: object)

# %% [markdown]
# ### 7. Analyzing Data
# ---

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import seaborn as sns
corr = data.corr()
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(13,7))
a = sns.heatmap(corr, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
sns.pairplot(data,hue='make')
# Out:
# C:\Users\Elijah\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\Elijah\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
plt.scatter(data['engine-size'],data['peak-rpm'])
plt.xlabel('Engine size')
plt.ylabel('Peak RPM');

# %% [markdown]
# ### 8. Reporting Results
# ---

# %% [markdown]
# After cleansing the data you can see that some of the coulmns had either missing values or incorrects formats. Now that everything is clean and set up properly you can view all the visuals the dataset has to offer from the images above in the analyitics sections and the images I'll provide below.

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base     length       width  \
# count  203.000000         203.000000  203.000000  203.00000  203.000000
# mean     0.837438         121.871921   98.781281  174.11330   65.915271
# std      1.250021          31.784599    6.040994   12.33909    2.150274
# min     -2.000000          65.000000   86.600000  141.10000   60.300000
# 25%      0.000000         101.000000   94.500000  166.55000   64.100000
# 50%      1.000000         122.000000   97.000000  173.20000   65.500000
# 75%      2.000000         137.000000  102.400000  183.30000   66.900000
# max      3.000000         256.000000  120.900000  208.10000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  203.000000   203.000000   203.000000  199.000000  199.000000
# mean    53.731527  2557.916256   127.073892    3.330955    3.254070
# std      2.442526   522.557049    41.797123    0.274054    0.318023
# ...

# %%
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Below shows a scatter plot that displays the make of a car with the dot colors and on the grid it shows the price of the car in relation to the horsepower. Unfortnetually there happens to be a car with over 13k horse in the dataset as an easter egg that make the graph look irregular.

# %%
sns.set_style('whitegrid')
sns.lmplot('price','horsepower',data=data,hue='make',fit_reg=False)

# %% [markdown]
# Below are two boxplots. One shows the price in relation to the number of doors while the later shows the price in relation to the type of body the car has.

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="num-of-doors", y="price", data=data)

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="body-style", y="price", data=data)

# %% [markdown]
# Below are two scatter plots showing showing the make with the x and y plots being the city and highway mpg in relation to the price

# %%
c = sns.lmplot('city-mpg',"price", data, hue="make", fit_reg=False);

# %%
e = sns.lmplot('highway-mpg',"price", data, hue="make",fit_reg=False);

# %% [markdown]
# Below shows two bar graphs with the Bodystyle of the car being shown in corolation to the City Miles Per Gallon and Highway Miles Per Gallon

# %%
data.groupby('body-style')['city-mpg'].mean().plot(kind='bar', color = 'blue');
plt.title("Body Style City MPG")
plt.ylabel('City MPG')
plt.xlabel('Body Style');

# %%
data.groupby('body-style')['highway-mpg'].mean().plot(kind='bar', color = 'blue');
plt.title("Body Style Highway MPG")
plt.ylabel('Highway MPG')
plt.xlabel('Body Style');

# %% [markdown]
# Below is a bar graph that shows the mean price of cars of certain body types

# %%
data.groupby('body-style')['price'].mean().plot(kind='bar', color = 'pink');
plt.title("Body Style - Price")
plt.ylabel('Price')
plt.xlabel('Body Style');

# %% [markdown]
# Below is a graph of the relation between the make of cars and the price of them on average

# %%
data.groupby('make')['price'].mean().plot(kind='bar', color = 'cyan');
plt.title("Make - Price")
plt.ylabel('Price')
plt.xlabel('Make');

# %%
data.groupby('make')['city-mpg'].mean().plot(kind='bar', color = 'purple');
plt.title("Make - City MPG")
plt.ylabel('City MPG')
plt.xlabel('Make');

# %%
data.groupby('make')['highway-mpg'].mean().plot(kind='bar', color = 'purple');
plt.title("Make - Highway MPG")
plt.ylabel('Highway MPG')
plt.xlabel('Make');

# %% [markdown]
# ### 9. Conclusion
# ---

# %% [markdown]
# Through my project, I have presented the data and cleaned it up. After cleansing the data, I showed the various graphs to showcase the amount of information the dataset has.
# With the graphs I showed correlations between different fields and how they are related.
# I also showcased the mileage based on City and Highway driving for various makes in addition to the prices.
# I also showed factors affecting the price of cars such as the body type, it's milage and the make.
